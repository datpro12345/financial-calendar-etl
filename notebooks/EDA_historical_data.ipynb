# %% [markdown]
# # Classification and Labeling of Financial Events Using Text Processing Techniques
#
# ### 1. **Business Understanding**
#    - **Objective**: The primary goal of this notebook is to categorize and label financial events based on their descriptions (event names). The objective is to systematically classify these events into specific financial indicators, such as GDP, CPI, PMI, and others, to facilitate further analysis of their impact on financial markets and economic forecasting.
#
# ### 2. **Data Understanding**
#    - **Data**: The dataset consists of a list of financial event names, each representing various economic indicators and events (e.g., "French Final Manufacturing PMI", "CPI m/m"). These event names vary in terms of content and structure.
#    - **Exploration**: Initial exploration involves examining the dataset to understand the variety of event names and identifying patterns, such as keywords that correspond to specific economic indicators (e.g., "CPI", "PMI").
#
# ### 3. **Data Preparation**
#    - **Processing**: The text data is preprocessed by converting all event names to lowercase and filtering or tokenizing key phrases such as "CPI", "PMI", "GDP", etc.
#    - **Categorization**: The event names are then categorized into predefined groups based on the identified keywords. This step includes creating a function to automatically classify each event into its respective category.
#
# ### 4. **Modeling**
#    - **Approach**: While not a traditional machine learning model, this notebook employs rule-based text classification to assign labels to each event. The rules are defined based on the presence of specific keywords within the event names.
#    - **Implementation**: The notebook uses Python's `pandas` library to group, filter, and classify the events, ensuring that each event is correctly categorized under its corresponding financial indicator.
#
# ### 5. **Evaluation**
#    - **Verification**: The effectiveness of the classification is verified by reviewing the grouped events to ensure that they have been accurately categorized. This is done by comparing the labeled categories against the expected economic indicators.
#    - **Outcome**: The evaluation may involve counting the number of events per category and assessing the distribution to ensure that no significant event types have been missed or misclassified.
#
# ### 6. **Deployment**
#    - **Application**: The final categorized dataset can be used in further analyses, such as impact assessment of specific economic indicators on markets, or it could be integrated into silver pipeline.
#    - **Future Steps**: Based on this classification, additional analyses or reports could be generated to provide insights into trends and patterns in the economic data.

# %% [markdown]
# ## 2. Data Understanding

# %% [markdown]
# ### Import lib and csv.

# %%
import pandas as pd
import numpy as np
import re
from collections import Counter

# %%
df_01 = pd.read_csv("/Users/datpro/Documents/gitdatpro/ff-transform-data/data/bronze/monthly/2024_01_ff_data.csv")
df_02 = pd.read_csv("/Users/datpro/Documents/gitdatpro/ff-transform-data/data/bronze/monthly/2024_02_ff_data.csv")
df_03 = pd.read_csv('/Users/datpro/Documents/gitdatpro/ff-transform-data/data/bronze/monthly/2024_03_ff_data.csv')
df_04 = pd.read_csv('/Users/datpro/Documents/gitdatpro/ff-transform-data/data/bronze/monthly/2024_04_ff_data.csv')
df_05 = pd.read_csv('/Users/datpro/Documents/gitdatpro/ff-transform-data/data/bronze/monthly/2024_05_ff_data.csv')
df_06 = pd.read_csv('/Users/datpro/Documents/gitdatpro/ff-transform-data/data/bronze/monthly/2024_06_ff_data.csv')
df_07 = pd.read_csv('/Users/datpro/Documents/gitdatpro/ff-transform-data/data/bronze/monthly/2024_07_ff_data.csv')
# df_07 = pd.read_csv('/Users/datpro/Documents/gitdatpro/ff-transform-data/data/bronze/monthly/2024_02_ff_data.csv')

# Combine all df to one 

df_combined = pd.concat([df_01, df_02, df_03, df_04, df_05, df_06, df_07], ignore_index=True)

# %%
# Check df
df_combined.head(3)
# Out:
#     date     time currency impact         event actual forecast previous
# 0  Jan 1  All Day      NZD   gray  Bank Holiday    NaN      NaN      NaN
# 1  Jan 1  All Day      AUD   gray  Bank Holiday    NaN      NaN      NaN
# 2  Jan 1  All Day      JPY   gray  Bank Holiday    NaN      NaN      NaN

# %% [markdown]
# ## Finding pattern and words count in event names

# %%
# Danh sách các sự kiện
event_name = df_combined['event'].unique()

# Tạo một danh sách để chứa các pattern
patterns = []

# Biểu thức chính quy để lọc các phần chung trong tên
pattern = re.compile(r'(CPI\s?[a-z/]*/?[a-z]*|PPI\s?[a-z/]*/?[a-z]*|PMI|GDP\s?[a-z/]*/?[a-z]*|Retail Sales\s?[a-z/]*/?[a-z]*|Unemployment Rate|Employment Change|Hourly Earnings\s?[a-z/]*/?[a-z]*)', re.IGNORECASE)

# Duyệt qua các sự kiện để tìm các pattern
for event in event_name:
    match = pattern.search(event)
    if match:
        patterns.append(match.group(0).strip())

# Đếm tần suất của các pattern tìm thấy
pattern_counts = Counter(patterns)

# Chuyển đổi kết quả thành DataFrame để dễ dàng hiển thị và phân tích
df_patterns = pd.DataFrame(pattern_counts.items(), columns=['Pattern', 'Frequency'])
df_patterns
# Out:
#                  Pattern  Frequency
# 0                    PMI         25
# 1      employment Change          2
# 2                CPI m/m          7
# 3      Employment Change          6
# 4       Retail Sales m/m          4
# 5              CPI Flash          2
# 6                PPI m/m          4
# 7      Unemployment Rate          4
# 8    Hourly Earnings m/m          1
# 9       Retail Sales y/y          1
# 10               CPI y/y         11
# 11  Retail Sales Monitor          1
# 12               PPI y/y          2
# 13               GDP m/m          1
# 14          GDP Estimate          1
# 15               GDP q/y          1
# 16             PPI Input          2
# 17            PPI Output          2
# 18               CPI q/q          2
# 19               GDP q/q         13
# 20             GDP Price          5
# 21               PPI q/q          1
# 22      Retail Sales q/q          2

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Danh sách các sự kiện
event_names = df_combined['event'].unique()

# Chuyển tất cả thành chữ thường
event_names = [event.lower() for event in event_names]

# Sử dụng CountVectorizer với n-grams
vectorizer = CountVectorizer(ngram_range=(2, 3), stop_words='english')  # Tạo ra bi-grams và tri-grams
X = vectorizer.fit_transform(event_names)
ngram_counts = dict(zip(vectorizer.get_feature_names_out(), X.toarray().sum(axis=0)))

# Sắp xếp n-grams theo tần suất xuất hiện giảm dần
sorted_ngram_counts = dict(sorted(ngram_counts.items(), key=lambda item: item[1], reverse=True))

# Hiển thị các n-grams phổ biến nhất
print("Top cụm từ phổ biến nhất:")
for ngram, count in sorted_ngram_counts.items():
    print(f"{ngram}: {count}")
# Out:
# Top cụm từ phổ biến nhất:
# fomc member: 14
# manufacturing pmi: 12
# monetary policy: 11
# services pmi: 10
# price index: 9
# mpc member: 8
# press conference: 8
# retail sales: 8
# bond auction: 7
# core cpi: 7
# industrial production: 7
# manufacturing index: 7
# employment change: 6
# financial stability: 6
# inflation expectations: 6
# prelim gdp: 6
# trade balance: 6
# 10 bond: 5
# 10 bond auction: 5
# gdp price: 5
# gdp price index: 5
# bank holiday: 4
# business confidence: 4
# council member: 4
# final gdp: 4
# financial stability report: 4
# flash gdp: 4
# french final: 4
# german final: 4
# gov council: 4
# gov council member: 4
# monetary policy report: 4
# policy report: 4
# stability report: 4
# unemployment rate: 4
# consumer confidence: 3
# consumer sentiment: 3
# final cpi: 3
# final manufacturing: 3
# final manufacturing pmi: 3
# final services: 3
# final services pmi: 3
# flash manufacturing: 3
# flash manufacturing pmi: 3
# flash services: 3
# flash services pmi: 3
# french flash: 3
# french prelim: 3
# home sales: 3
# import prices: 3
# meeting minutes: 3
# monetary policy statement: 3
# money supply: 3
# parliamentary elections: 3
# policy statement: 3
# prelim cpi: 3
# rate statement: 3
# 30 bond: 2
# 30 bond auction: 2
# advance gdp: 2
# assist gov: 2
# bank rate: 2
# board member: 2
# budget balance: 2
# building permits: 2
# business climate: 2
# business investment: 2
# cash rate: 2
# chair powell: 2
# commodity prices: 2
# consumer climate: 2
# core retail: 2
# core retail sales: 2
# cost index: 2
# cpi flash: 2
# cpi flash estimate: 2
# durable goods: 2
# durable goods orders: 2
# economic forecasts: 2
# economic sentiment: 2
# factory orders: 2
# farm employment: 2
# farm employment change: 2
# fed chair: 2
# fed chair powell: 2
# final gdp price: 2
# financial stability review: 2
# flash estimate: 2
# german buba: 2
# german flash: 2
# german prelim: 2
# gfk consumer: 2
# goods orders: 2
# gov board: 2
# gov board member: 2
# housing starts: 2
# investment ytd: 2
# ism manufacturing: 2
# italian prelim: 2
# labor costs: 2
# leading index: 2
# loan prime: 2
# loan prime rate: 2
# m2 money: 2
# manufacturing sales: 2
# mi inflation: 2
# monetary policy meeting: 2
# new home: 2
# non farm: 2
# non farm employment: 2
# non manufacturing: 2
# nonfarm productivity: 2
# official bank: 2
# official bank rate: 2
# policy meeting: 2
# policy rate: 2
# ppi input: 2
# ppi output: 2
# prelim gdp price: 2
# prelim uom: 2
# prime rate: 2
# private payrolls: 2
# quarterly bulletin: 2
# rba assist: 2
# rba assist gov: 2
# revised uom: 2
# spanish flash: 2
# spanish unemployment: 2
# stability review: 2
# unemployment change: 2
# unit labor: 2
# unit labor costs: 2
# uom consumer: 2
# uom consumer sentiment: 2
# uom inflation: 2
# uom inflation expectations: 2
# wholesale inventories: 2
# zew economic: 2
# zew economic sentiment: 2
# 20 hpi: 1
# 3m 3m: 1
# adp non: 1
# adp non farm: 1
# advance gdp price: 1
# annual budget: 1
# annual budget release: 1
# anz business: 1
# anz business confidence: 1
# anz commodity: 1
# anz commodity prices: 1
# anz job: 1
# anz job advertisements: 1
# asset investment: 1
# asset investment ytd: 1
# assist gov hunter: 1
# assist gov kent: 1
# average cash: 1
# average cash earnings: 1
# average earnings: 1
# average earnings index: 1
# average hourly: 1
# average hourly earnings: 1
# bailey speaks: 1
# bank lending: 1
# bank rate votes: 1
# bank stress: 1
# bank stress test: 1
# barkin speaks: 1
# barr speaks: 1
# beige book: 1
# belgian nbb: 1
# belgian nbb business: 1
# biden speaks: 1
# board member martin: 1
# board member schlegel: 1
# boc business: 1
# boc business outlook: 1
# boc financial: 1
# boc financial review: 1
# boc gov: 1
# boc gov macklem: 1
# boc monetary: 1
# boc monetary policy: 1
# boc press: 1
# boc press conference: 1
# boc rate: 1
# boc rate statement: 1
# boc summary: 1
# boc summary deliberations: 1
# boe credit: 1
# boe credit conditions: 1
# boe financial: 1
# boe financial stability: 1
# boe gov: 1
# boe gov bailey: 1
# boe inflation: 1
# boe inflation letter: 1
# boe monetary: 1
# boe monetary policy: 1
# boe quarterly: 1
# boe quarterly bulletin: 1
# boj core: 1
# boj core cpi: 1
# boj gov: 1
# boj gov ueda: 1
# boj outlook: 1
# boj outlook report: 1
# boj policy: 1
# boj policy rate: 1
# boj press: 1
# boj press conference: 1
# boj summary: 1
# boj summary opinions: 1
# bostic speaks: 1
# bowman speaks: 1
# brc retail: 1
# brc retail sales: 1
# brc shop: 1
# brc shop price: 1
# breeden speaks: 1
# broadbent speaks: 1
# bsi manufacturing: 1
# bsi manufacturing index: 1
# buba monthly: 1
# buba monthly report: 1
# buba president: 1
# buba president nagel: 1
# budget release: 1
# building approvals: 1
# building consents: 1
# bullock speaks: 1
# business index: 1
# business inventories: 1
# business outlook: 1
# business outlook survey: 1
# businessnz manufacturing: 1
# businessnz manufacturing index: 1
# businessnz services: 1
# businessnz services index: 1
# caixin manufacturing: 1
# caixin manufacturing pmi: 1
# caixin services: 1
# caixin services pmi: 1
# capacity utilization: 1
# capacity utilization rate: 1
# capital expenditure: 1
# capital spending: 1
# card spending: 1
# cash earnings: 1
# cb consumer: 1
# cb consumer confidence: 1
# cb leading: 1
# cb leading index: 1
# cbi industrial: 1
# cbi industrial order: 1
# cbi realized: 1
# cbi realized sales: 1
# chair powell speaks: 1
# chair powell testifies: 1
# chairman jordan: 1
# chairman jordan speaks: 1
# challenger job: 1
# challenger job cuts: 1
# chicago pmi: 1
# claimant count: 1
# claimant count change: 1
# cleveland fed: 1
# cleveland fed inflation: 1
# common cpi: 1
# company operating: 1
# company operating profits: 1
# composite 20: 1
# composite 20 hpi: 1
# conditions survey: 1
# construction output: 1
# construction pmi: 1
# construction spending: 1
# construction work: 1
# consumer credit: 1
# consumer inflation: 1
# consumer inflation expectations: 1
# consumer spending: 1
# cook speaks: 1
# core cpi flash: 1
# core durable: 1
# core durable goods: 1
# core machinery: 1
# core machinery orders: 1
# core pce: 1
# core pce price: 1
# core ppi: 1
# corporate profits: 1
# council member gravelle: 1
# council member kozicki: 1
# council member mendes: 1
# council member rogers: 1
# count change: 1
# credit card: 1
# credit card spending: 1
# credit conditions: 1
# credit conditions survey: 1
# crude oil: 1
# crude oil inventories: 1
# cs composite: 1
# cs composite 20: 1
# currency report: 1
# currency reserves: 1
# current account: 1
# daly speaks: 1
# daylight saving: 1
# daylight saving time: 1
# denominated trade: 1
# denominated trade balance: 1
# deputy gov: 1
# deputy gov hauser: 1
# dhingra speaks: 1
# direct investment: 1
# direct investment ytd: 1
# earnings index: 1
# earnings index 3m: 1
# ecb economic: 1
# ecb economic bulletin: 1
# ecb financial: 1
# ecb financial stability: 1
# ecb monetary: 1
# ecb monetary policy: 1
# ecb president: 1
# ecb president lagarde: 1
# ecb press: 1
# ecb press conference: 1
# ecofin meetings: 1
# economic barometer: 1
# economic bulletin: 1
# economic expectations: 1
# economic optimism: 1
# economic projections: 1
# economy watchers: 1
# economy watchers sentiment: 1
# empire state: 1
# empire state manufacturing: 1
# employment cost: 1
# employment cost index: 1
# equity withdrawal: 1
# eu economic: 1
# eu economic forecasts: 1
# euro summit: 1
# eurogroup meetings: 1
# european parliamentary: 1
# european parliamentary elections: 1
# existing home: 1
# existing home sales: 1
# fed inflation: 1
# fed inflation expectations: 1
# fed manufacturing: 1
# fed manufacturing index: 1
# fed monetary: 1
# fed monetary policy: 1
# federal budget: 1
# federal budget balance: 1
# federal funds: 1
# federal funds rate: 1
# final core: 1
# final core cpi: 1
# final employment: 1
# final employment change: 1
# final private: 1
# final private payrolls: 1
# final wholesale: 1
# final wholesale inventories: 1
# financial review: 1
# fixed asset: 1
# fixed asset investment: 1
# flash cpi: 1
# flash employment: 1
# flash employment change: 1
# fomc economic: 1
# fomc economic projections: 1
# fomc financial: 1
# fomc financial stability: 1
# fomc meeting: 1
# fomc meeting minutes: 1
# fomc member barkin: 1
# fomc member barr: 1
# fomc member bostic: 1
# fomc member bowman: 1
# fomc member cook: 1
# fomc member daly: 1
# fomc member goolsbee: 1
# fomc member jefferson: 1
# fomc member kugler: 1
# fomc member logan: 1
# fomc member mester: 1
# fomc member musalem: 1
# fomc member waller: 1
# fomc member williams: 1
# fomc press: 1
# fomc press conference: 1
# fomc statement: 1
# foreign currency: 1
# foreign currency reserves: 1
# foreign direct: 1
# foreign direct investment: 1
# foreign securities: 1
# foreign securities purchases: 1
# fpc meeting: 1
# fpc meeting minutes: 1
# fpc statement: 1
# french 10: 1
# french 10 bond: 1
# french bank: 1
# french bank holiday: 1
# french consumer: 1
# french consumer spending: 1
# french final cpi: 1
# french final manufacturing: 1
# french final private: 1
# french final services: 1
# french flash gdp: 1
# french flash manufacturing: 1
# french flash services: 1
# french gov: 1
# french gov budget: 1
# french industrial: 1
# french industrial production: 1
# french parliamentary: 1
# french parliamentary elections: 1
# french prelim cpi: 1
# french prelim gdp: 1
# french prelim private: 1
# french trade: 1
# french trade balance: 1
# funds rate: 1
# gas storage: 1
# gdp estimate: 1
# gdt price: 1
# gdt price index: 1
# german 10: 1
# german 10 bond: 1
# german 30: 1
# german 30 bond: 1
# german bank: 1
# german bank holiday: 1
# german buba monthly: 1
# german buba president: 1
# german factory: 1
# german factory orders: 1
# german final cpi: 1
# german final gdp: 1
# german final manufacturing: 1
# german final services: 1
# german flash manufacturing: 1
# german flash services: 1
# german gfk: 1
# german gfk consumer: 1
# german ifo: 1
# german ifo business: 1
# german import: 1
# german import prices: 1
# german industrial: 1
# german industrial production: 1
# german ppi: 1
# german prelim cpi: 1
# german prelim gdp: 1
# german retail: 1
# german retail sales: 1
# german trade: 1
# german trade balance: 1
# german unemployment: 1
# german unemployment change: 1
# german wpi: 1
# german zew: 1
# german zew economic: 1
# gfk consumer climate: 1
# gfk consumer confidence: 1
# goods trade: 1
# goods trade balance: 1
# goolsbee speaks: 1
# gov bailey: 1
# gov bailey speaks: 1
# gov budget: 1
# gov budget balance: 1
# gov bullock: 1
# gov bullock speaks: 1
# gov hauser: 1
# gov hauser speaks: 1
# gov hunter: 1
# gov hunter speaks: 1
# gov kent: 1
# gov kent speaks: 1
# gov macklem: 1
# gov macklem speaks: 1
# gov orr: 1
# gov orr speaks: 1
# gov ueda: 1
# gov ueda speaks: 1
# gravelle speaks: 1
# greene speaks: 1
# halifax hpi: 1
# haskel speaks: 1
# hauser speaks: 1
# home prices: 1
# hourly earnings: 1
# house price: 1
# house price balance: 1
# household spending: 1
# housing equity: 1
# housing equity withdrawal: 1
# housing market: 1
# housing market index: 1
# hunter speaks: 1
# ifo business: 1
# ifo business climate: 1
# index 3m: 1
# index services: 1
# index services 3m: 1
# industrial order: 1
# industrial order expectations: 1
# industry activity: 1
# inflation gauge: 1
# inflation letter: 1
# investor confidence: 1
# ism manufacturing pmi: 1
# ism manufacturing prices: 1
# ism services: 1
# ism services pmi: 1
# italian 10: 1
# italian 10 bond: 1
# italian bank: 1
# italian bank holiday: 1
# italian industrial: 1
# italian industrial production: 1
# italian manufacturing: 1
# italian manufacturing pmi: 1
# italian monthly: 1
# italian monthly unemployment: 1
# italian prelim cpi: 1
# italian prelim gdp: 1
# italian quarterly: 1
# italian quarterly unemployment: 1
# italian retail: 1
# italian retail sales: 1
# italian services: 1
# italian services pmi: 1
# italian trade: 1
# italian trade balance: 1
# ivey pmi: 1
# jefferson speaks: 1
# job advertisements: 1
# job cuts: 1
# job openings: 1
# jolts job: 1
# jolts job openings: 1
# jordan speaks: 1
# kent speaks: 1
# kof economic: 1
# kof economic barometer: 1
# kozicki speaks: 1
# kugler speaks: 1
# labor cost: 1
# labor cost index: 1
# labor productivity: 1
# lagarde speaks: 1
# leading indicators: 1
# lending individuals: 1
# loan officer: 1
# loan officer survey: 1
# logan speaks: 1
# long term: 1
# long term purchases: 1
# m2 money stock: 1
# m2 money supply: 1
# m3 money: 1
# m3 money supply: 1
# m4 money: 1
# m4 money supply: 1
# machine tool: 1
# machine tool orders: 1
# machinery orders: 1
# macklem speaks: 1
# main refinancing: 1
# main refinancing rate: 1
# mann speaks: 1
# manufacturing prices: 1
# manufacturing production: 1
# market index: 1
# martin speaks: 1
# mean cpi: 1
# median cpi: 1
# meeting accounts: 1
# member barkin: 1
# member barkin speaks: 1
# member barr: 1
# member barr speaks: 1
# member bostic: 1
# member bostic speaks: 1
# member bowman: 1
# member bowman speaks: 1
# member breeden: 1
# member breeden speaks: 1
# member broadbent: 1
# member broadbent speaks: 1
# member cook: 1
# member cook speaks: 1
# member daly: 1
# member daly speaks: 1
# member dhingra: 1
# member dhingra speaks: 1
# member goolsbee: 1
# member goolsbee speaks: 1
# member gravelle: 1
# member gravelle speaks: 1
# member greene: 1
# member greene speaks: 1
# member haskel: 1
# member haskel speaks: 1
# member jefferson: 1
# member jefferson speaks: 1
# member kozicki: 1
# member kozicki speaks: 1
# member kugler: 1
# member kugler speaks: 1
# member logan: 1
# member logan speaks: 1
# member mann: 1
# member mann speaks: 1
# member martin: 1
# member martin speaks: 1
# member mendes: 1
# member mendes speaks: 1
# member mester: 1
# member mester speaks: 1
# member musalem: 1
# member musalem speaks: 1
# member pill: 1
# member pill speaks: 1
# member ramsden: 1
# member ramsden speaks: 1
# member rogers: 1
# member rogers speaks: 1
# member schlegel: 1
# member schlegel speaks: 1
# member waller: 1
# member waller speaks: 1
# member williams: 1
# member williams speaks: 1
# mendes speaks: 1
# mester speaks: 1
# mi inflation expectations: 1
# mi inflation gauge: 1
# mi leading: 1
# mi leading index: 1
# monetary base: 1
# monetary policy assessment: 1
# monetary policy summary: 1
# money stock: 1
# monthly report: 1
# monthly unemployment: 1
# monthly unemployment rate: 1
# mortgage approvals: 1
# mortgage delinquencies: 1
# mpc member breeden: 1
# mpc member broadbent: 1
# mpc member dhingra: 1
# mpc member greene: 1
# mpc member haskel: 1
# mpc member mann: 1
# mpc member pill: 1
# mpc member ramsden: 1
# mpc official: 1
# mpc official bank: 1
# musalem speaks: 1
# nab business: 1
# nab business confidence: 1
# nab quarterly: 1
# nab quarterly business: 1
# nagel speaks: 1
# nahb housing: 1
# nahb housing market: 1
# national core: 1
# national core cpi: 1
# nationwide hpi: 1
# natural gas: 1
# natural gas storage: 1
# nbb business: 1
# nbb business climate: 1
# nbs press: 1
# nbs press conference: 1
# net borrowing: 1
# net lending: 1
# net lending individuals: 1
# new home prices: 1
# new home sales: 1
# new loans: 1
# nfib small: 1
# nfib small business: 1
# niesr gdp: 1
# niesr gdp estimate: 1
# non manufacturing index: 1
# non manufacturing pmi: 1
# nzier business: 1
# nzier business confidence: 1
# officer survey: 1
# official cash: 1
# official cash rate: 1
# oil inventories: 1
# operating profits: 1
# order expectations: 1
# orr speaks: 1
# outlook report: 1
# outlook survey: 1
# overnight rate: 1
# overseas trade: 1
# overseas trade index: 1
# pce price: 1
# pce price index: 1
# pending home: 1
# pending home sales: 1
# personal income: 1
# personal spending: 1
# philly fed: 1
# philly fed manufacturing: 1
# pill speaks: 1
# policy assessment: 1
# policy meeting accounts: 1
# policy meeting minutes: 1
# policy report hearings: 1
# policy summary: 1
# powell speaks: 1
# powell testifies: 1
# prelim business: 1
# prelim business investment: 1
# prelim flash: 1
# prelim flash gdp: 1
# prelim industrial: 1
# prelim industrial production: 1
# prelim machine: 1
# prelim machine tool: 1
# prelim nonfarm: 1
# prelim nonfarm productivity: 1
# prelim private: 1
# prelim private payrolls: 1
# prelim unit: 1
# prelim unit labor: 1
# prelim uom consumer: 1
# prelim uom inflation: 1
# prelim wholesale: 1
# prelim wholesale inventories: 1
# president biden: 1
# president biden speaks: 1
# president lagarde: 1
# president lagarde speaks: 1
# president nagel: 1
# president nagel speaks: 1
# price balance: 1
# private capital: 1
# private capital expenditure: 1
# private loans: 1
# private sector: 1
# private sector credit: 1
# public sector: 1
# public sector net: 1
# quarterly business: 1
# quarterly business confidence: 1
# quarterly unemployment: 1
# quarterly unemployment rate: 1
# ramsden speaks: 1
# rate votes: 1
# rba bulletin: 1
# rba deputy: 1
# rba deputy gov: 1
# rba financial: 1
# rba financial stability: 1
# rba gov: 1
# rba gov bullock: 1
# rba monetary: 1
# rba monetary policy: 1
# rba press: 1
# rba press conference: 1
# rba rate: 1
# rba rate statement: 1
# rbnz financial: 1
# rbnz financial stability: 1
# rbnz gov: 1
# rbnz gov orr: 1
# rbnz monetary: 1
# rbnz monetary policy: 1
# rbnz press: 1
# rbnz press conference: 1
# rbnz rate: 1
# rbnz rate statement: 1
# rbnz statement: 1
# rbnz statement intent: 1
# rcm tipp: 1
# rcm tipp economic: 1
# realized sales: 1
# refinancing rate: 1
# report hearings: 1
# retail sales monitor: 1
# revised business: 1
# revised business investment: 1
# revised gdp: 1
# revised industrial: 1
# revised industrial production: 1
# revised nonfarm: 1
# revised nonfarm productivity: 1
# revised unit: 1
# revised unit labor: 1
# revised uom consumer: 1
# revised uom inflation: 1
# richmond manufacturing: 1
# richmond manufacturing index: 1
# rics house: 1
# rics house price: 1
# rightmove hpi: 1
# rogers speaks: 1
# sales monitor: 1
# saving time: 1
# saving time shift: 1
# schlegel speaks: 1
# sec yellen: 1
# sec yellen speaks: 1
# seco consumer: 1
# seco consumer climate: 1
# seco economic: 1
# seco economic forecasts: 1
# sector credit: 1
# sector net: 1
# sector net borrowing: 1
# securities purchases: 1
# sentix investor: 1
# sentix investor confidence: 1
# services 3m: 1
# services 3m 3m: 1
# services index: 1
# shop price: 1
# shop price index: 1
# small business: 1
# small business index: 1
# snb chairman: 1
# snb chairman jordan: 1
# snb financial: 1
# snb financial stability: 1
# snb monetary: 1
# snb monetary policy: 1
# snb policy: 1
# snb policy rate: 1
# snb press: 1
# snb press conference: 1
# snb quarterly: 1
# snb quarterly bulletin: 1
# spanish 10: 1
# spanish 10 bond: 1
# spanish flash cpi: 1
# spanish flash gdp: 1
# spanish manufacturing: 1
# spanish manufacturing pmi: 1
# spanish services: 1
# spanish services pmi: 1
# spanish unemployment change: 1
# spanish unemployment rate: 1
# state manufacturing: 1
# state manufacturing index: 1
# statement intent: 1
# stress test: 1
# stress test results: 1
# summary deliberations: 1
# summary opinions: 1
# tankan manufacturing: 1
# tankan manufacturing index: 1
# tankan non: 1
# tankan non manufacturing: 1
# term purchases: 1
# tertiary industry: 1
# tertiary industry activity: 1
# test results: 1
# tic long: 1
# tic long term: 1
# time shift: 1
# tipp economic: 1
# tipp economic optimism: 1
# tokyo core: 1
# tokyo core cpi: 1
# tool orders: 1
# total vehicle: 1
# total vehicle sales: 1
# trade index: 1
# treasury currency: 1
# treasury currency report: 1
# treasury sec: 1
# treasury sec yellen: 1
# trimmed cpi: 1
# trimmed mean: 1
# trimmed mean cpi: 1
# ubs economic: 1
# ubs economic expectations: 1
# ueda speaks: 1
# unemployment claims: 1
# usd denominated: 1
# usd denominated trade: 1
# utilization rate: 1
# vehicle sales: 1
# visitor arrivals: 1
# wage price: 1
# wage price index: 1
# waller speaks: 1
# wards total: 1
# wards total vehicle: 1
# watchers sentiment: 1
# westpac consumer: 1
# westpac consumer sentiment: 1
# wholesale sales: 1
# williams speaks: 1
# yellen speaks: 1

# %% [markdown]
# #### Single word count

# %%
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer

# Chuyển tất cả thành chữ thường
event_names = [event.lower() for event in event_names]

# Sử dụng CountVectorizer để đếm tần suất từ
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(event_names)
word_counts = dict(zip(vectorizer.get_feature_names_out(), X.toarray().sum(axis=0)))

# Sắp xếp từ theo tần suất xuất hiện giảm dần
sorted_word_counts = dict(sorted(word_counts.items(), key=lambda item: item[1], reverse=True))

# Hiển thị các từ phổ biến nhất
print("Top từ phổ biến nhất:")
for word, count in sorted_word_counts.items():
    print(f"{word}: {count}")
# Out:
# Top từ phổ biến nhất:
# speaks: 42
# member: 28
# index: 26
# pmi: 25
# german: 24
# manufacturing: 23
# cpi: 22
# gdp: 21
# fomc: 19
# prelim: 19
# rate: 19
# final: 17
# french: 17
# sales: 16
# gov: 15
# flash: 14
# core: 13
# policy: 13
# monetary: 12
# services: 12
# business: 11
# consumer: 11
# italian: 11
# report: 11
# price: 10
# balance: 9
# change: 9
# economic: 9
# mpc: 9
# ppi: 9
# rba: 9
# statement: 9
# bank: 8
# conference: 8
# confidence: 8
# expectations: 8
# industrial: 8
# inflation: 8
# press: 8
# production: 8
# retail: 8
# auction: 7
# boc: 7
# bond: 7
# employment: 7
# financial: 7
# prices: 7
# revised: 7
# spanish: 7
# trade: 7
# unemployment: 7
# boe: 6
# boj: 6
# hpi: 6
# orders: 6
# rbnz: 6
# sentiment: 6
# snb: 6
# spending: 6
# stability: 6
# 10: 5
# ecb: 5
# fed: 5
# private: 5
# building: 4
# bulletin: 4
# climate: 4
# construction: 4
# council: 4
# credit: 4
# holiday: 4
# home: 4
# housing: 4
# inventories: 4
# investment: 4
# labor: 4
# meeting: 4
# money: 4
# non: 4
# of: 4
# quarterly: 4
# uom: 4
# 3m: 3
# anz: 3
# average: 3
# budget: 3
# cash: 3
# earnings: 3
# elections: 3
# estimate: 3
# foreign: 3
# goods: 3
# import: 3
# ism: 3
# job: 3
# leading: 3
# loan: 3
# mi: 3
# minutes: 3
# new: 3
# official: 3
# output: 3
# parliamentary: 3
# president: 3
# productivity: 3
# review: 3
# summary: 3
# supply: 3
# survey: 3
# wholesale: 3
# 30: 2
# advance: 2
# approvals: 2
# assist: 2
# board: 2
# brc: 2
# buba: 2
# businessnz: 2
# caixin: 2
# capital: 2
# cb: 2
# cbi: 2
# chair: 2
# commodity: 2
# cost: 2
# costs: 2
# currency: 2
# durable: 2
# factory: 2
# farm: 2
# federal: 2
# forecasts: 2
# fpc: 2
# gfk: 2
# input: 2
# lending: 2
# loans: 2
# m2: 2
# meetings: 2
# monthly: 2
# mortgage: 2
# nab: 2
# net: 2
# nonfarm: 2
# outlook: 2
# payrolls: 2
# permits: 2
# personal: 2
# powell: 2
# prime: 2
# profits: 2
# purchases: 2
# seco: 2
# sector: 2
# starts: 2
# tankan: 2
# treasury: 2
# trimmed: 2
# unit: 2
# ytd: 2
# zew: 2
# 20: 1
# account: 1
# accounts: 1
# activity: 1
# adp: 1
# advertisements: 1
# annual: 1
# arrivals: 1
# assessment: 1
# asset: 1
# bailey: 1
# barkin: 1
# barometer: 1
# barr: 1
# base: 1
# beige: 1
# belgian: 1
# biden: 1
# book: 1
# borrowing: 1
# bostic: 1
# bowman: 1
# breeden: 1
# broadbent: 1
# bsi: 1
# bullock: 1
# capacity: 1
# card: 1
# chairman: 1
# challenger: 1
# chicago: 1
# claimant: 1
# claims: 1
# cleveland: 1
# common: 1
# company: 1
# composite: 1
# conditions: 1
# consents: 1
# cook: 1
# corporate: 1
# count: 1
# crude: 1
# cs: 1
# current: 1
# cuts: 1
# daly: 1
# daylight: 1
# deliberations: 1
# delinquencies: 1
# denominated: 1
# deputy: 1
# dhingra: 1
# direct: 1
# done: 1
# ecofin: 1
# economy: 1
# empire: 1
# equity: 1
# eu: 1
# euro: 1
# eurogroup: 1
# european: 1
# existing: 1
# expenditure: 1
# fixed: 1
# fpi: 1
# funds: 1
# gas: 1
# gauge: 1
# gdt: 1
# goolsbee: 1
# gravelle: 1
# greene: 1
# halifax: 1
# haskel: 1
# hauser: 1
# hearings: 1
# hourly: 1
# house: 1
# household: 1
# hunter: 1
# ifo: 1
# income: 1
# indicators: 1
# individuals: 1
# industry: 1
# intent: 1
# investor: 1
# ippi: 1
# ivey: 1
# jefferson: 1
# jolts: 1
# jordan: 1
# kent: 1
# kof: 1
# kozicki: 1
# kugler: 1
# lagarde: 1
# letter: 1
# logan: 1
# long: 1
# m3: 1
# m4: 1
# machine: 1
# machinery: 1
# macklem: 1
# main: 1
# mann: 1
# market: 1
# martin: 1
# mean: 1
# median: 1
# mendes: 1
# mester: 1
# monitor: 1
# musalem: 1
# nagel: 1
# nahb: 1
# national: 1
# nationwide: 1
# natural: 1
# nbb: 1
# nbs: 1
# nfib: 1
# nhpi: 1
# niesr: 1
# nzier: 1
# officer: 1
# oil: 1
# openings: 1
# operating: 1
# opinions: 1
# optimism: 1
# order: 1
# orr: 1
# overnight: 1
# overseas: 1
# pce: 1
# pending: 1
# philly: 1
# pill: 1
# projections: 1
# public: 1
# ramsden: 1
# rcm: 1
# realized: 1
# refinancing: 1
# release: 1
# reserves: 1
# results: 1
# richmond: 1
# rics: 1
# rightmove: 1
# rmpi: 1
# rogers: 1
# rpi: 1
# saving: 1
# schlegel: 1
# sec: 1
# securities: 1
# sentix: 1
# shift: 1
# shop: 1
# small: 1
# sppi: 1
# state: 1
# stock: 1
# storage: 1
# stress: 1
# summit: 1
# system: 1
# term: 1
# tertiary: 1
# test: 1
# testifies: 1
# tic: 1
# time: 1
# tipp: 1
# to: 1
# tokyo: 1
# tool: 1
# total: 1
# ubs: 1
# ueda: 1
# usd: 1
# utilization: 1
# vehicle: 1
# visitor: 1
# votes: 1
# wage: 1
# waller: 1
# wards: 1
# watchers: 1
# westpac: 1
# williams: 1
# withdrawal: 1
# work: 1
# wpi: 1
# yellen: 1

# %% [markdown]
# ### **Classification: A Three-Level Categorization**
#
# #### **1. Word Analysis to Level 1 Classification (Primary Category):**
#
# - **Why**: The word count analysis helps identify key terms that frequently appear in event names. By identifying these key terms, we can categorize events into broad **Primary Categories** (Level 1) such as GDP, Inflation, Bond, etc. This initial categorization organizes the information systematically, laying the foundation for more detailed analysis.
#
# - **How**: Based on the key terms identified from the word count (e.g., "gdp", "inflation", "bond"), we group related events into their corresponding **Primary Categories**.
#
# #### **2. Level 1 Classification (Primary Category):**
#
# - **Definition**:
#   - **GDP**: Events related to Gross Domestic Product.
#   - **Inflation**: Events related to inflation metrics.
#   - **Bond**: Events related to bonds and bond auctions.
#   - **Employment Indicators**: Events related to the labor market.
#   - **Production Indicators**: Events related to industrial production and factory orders.
#   - **Sales Indicators**: Events related to sales figures, such as retail and home sales.
#   - **Speak**: Speeches and statements from financial leaders.
#   - **Submit**: Financial reports and documents submitted.
#   - **Monetary Policy**: Events related to monetary policy decisions.
#   - **Holiday**: Public holidays and bank holidays.
#   - **Other**: Events that do not fit into the above categories.
#
# #### **3. Level 2 Classification (Reporting Type + Event Name):**
#
# - **Why**: Events that share the same indicator might have multiple versions, such as "Prelim", "Final", "Flash", etc. Combining **Reporting Type** with **Event Name** in Level 2 allows for precise classification of the report type and the specific indicator.
#
# - **How**:
#   - We use keywords like "prelim", "final", "flash", etc., combined with specific indicator names like "CPI", "GDP", "Inflation Expectations", to classify events at Level 2.
#   - For example, "Prelim UoM Inflation Expectations" is classified as having a **Reporting Type** of "Prelim" and an **Event Name** of "Inflation Expectations".
# - **Refinement** :
#     - After classifying events into Level 1 categories, we review those that remain unspecified or not clearly labeled according to the Level 2 formula. We then further classify these events correctly to minimize the number of unspecified entries, ensuring that each event is accurately labeled according to the defined pattern.
#
# #### **4. Level 3 Classification (Time Frame):**
#
# - **Why**: The time frame (m/m, y/y, q/q, etc.) indicates the period over which the event or indicator is measured. Classifying events by **Time Frame** adds an additional layer of detail, providing insights into the time-related context of the indicator.
#
# - **How**:
#   - We use keywords related to time frames such as "m/m", "y/y", "q/q" to classify events at Level 3.
#   - For example, "MI Inflation Gauge m/m" has a **Time Frame** of "m/m", indicating that this indicator is measured month-over-month.
# - **Refinement** :
#     - Similar to Level 2, we examine any events that remain unspecified after Level 2 classification. We apply the defined time frame patterns to ensure these events are accurately classified in Level 3, reducing the likelihood of unspecified entries.
#
# ### **Summary:**
#
# - **Level 1**: Identifies the primary category of the event based on key terms (e.g., GDP, Inflation, Bond).
# - **Level 2**: Combines the reporting type with the specific indicator name for detailed classification.
# - **Level 3**: Adds further granularity by classifying events based on the time frame over which the indicator is measured.
#
# This classification approach ensures that data is organized logically and systematically, facilitating deeper analysis of economic events.

# %%
# Hàm để phân loại các sự kiện
def categorize_event(event_name):
    event_name = event_name.lower()

    # Define categories for Level 1
    primary_categories = {
        'gdp': ['gdp'],
        'inflation': ['cpi', 'core cpi', 'ppi', 'inflation', 'pce'],
        'bond': ['bond', 'auction', 'treasury'],
        'employment indicators': ['employment', 'jolts job openings', 'unemployment', 'claimant count change'],  # Updated
        'production indicators': ['industrial production', 'factory orders', 'pmi'],
        'sales indicators': ['retail sales', 'new home sales', 'pending home sales'],
        'speak': ['speaks', 'testifies', 'press conference'],
        'submit': ['release', 'projections', 'budget'],
        'monetary policy': ['monetary policy', 'rate statement', 'meeting minutes', 'policy rate', 'official bank rate',
                            'cash rate', 'overnight rate', 'main refinancing rate', 'federal funds rate', 'boj outlook report', 'fomc statement'],  # Updated
        'political events': ['elections', 'summit', 'meetings'],  # Updated
        'economic indicators': ['consumer sentiment', 'consumer confidence', 'manufacturing index'],  # Updated
        'holiday': ['bank holiday', 'public holiday'],
        'other': [] # Other categories will go here
    }

    # Level 2 - Reporting Type + Specific Index
    level_2_categories = {
        
        # lv1: gdp
        'final gdp': ['final gdp'],
        'prelim gdp': ['prelim gdp'],
        'advance gdp': ['advance gdp'],  
        'gdp flash estimate': ['gdp flash estimate', 'flash gdp'], 
        'revised gdp': ['revised gdp'],  
        'gdp price index': ['gdp price index'], 
        'gdp estimate': ['gdp estimate', 'niesr gdp estimate'],  
        'gdp general': ['gdp m/m', 'gdp q/y', 'gdp q/q'],  
        
        # lv1: inflation (cpi / ppi / pce)
        'prelim cpi': ['prelim cpi'],
        'flash cpi': ['flash cpi', 'cpi flash estimate', 'flash estimate cpi'],
        'general cpi': ['cpi m/m', 'cpi y/y', 'cpi q/q'],
        'core cpi': ['core cpi'],
        'median cpi': ['median cpi'],
        'trimmed cpi': ['trimmed cpi'],
        'common cpi': ['common cpi'],
        'ppi input': ['ppi input'],
        'ppi output': ['ppi output'],
        'general ppi': ['ppi m/m', 'ppi y/y', 'ppi q/q', 'german ppi m/m', 'ippi m/m'],
        'core ppi': ['core ppi'],
        'sppi': ['sppi y/y'],
        'core pce': ['core pce price index m/m'],
        'trimmed mean cpi': ['trimmed mean cpi q/q'],
        'inflation expectations': [
            'mi inflation expectations',
            'prelim uom inflation expectations',
            'revised uom inflation expectations',
            'cleveland fed inflation expectations',
            'consumer inflation expectations'],
        'inflation letter': ['boe inflation letter'],
        
        # lv1 : bond
        'bond auction': ['bond auction'],
        'treasury speak': ['treasury sec yellen speaks'],  # Chỉ cần từ 'treasury' và 'speak'
        'treasury report': ['treasury currency report'],
        
        # lv1: employee indicators
        'unemployment rate': ['unemployment rate'],
        'employment change': ['employment change', 'non-farm employment change', 'adp non-farm employment change'],
        'unemployment claims': ['unemployment claims', 'unemployment change'],
        'job openings': ['job openings', 'jolts job openings'],
        'employment cost index': ['employment cost index'],

        # lv1: production indicators
        'manufacturing pmi': [
            'manufacturing pmi', 'caixin manufacturing pmi', 'spanish manufacturing pmi',
            'italian manufacturing pmi', 'french final manufacturing pmi',
            'german final manufacturing pmi', 'final manufacturing pmi', 'ism manufacturing pmi'],
        'services pmi': ['services pmi', 'caixin services pmi', 'spanish services pmi'],
        
        #lv1: retail sales
        'retail sales': ['retail sales', 'german retail sales', 'italian retail sales','brc retail sales monitor'],
        'core retail sales': ['core retail sales'],
        'new home sales': ['new home sales'],
        'pending home sales': ['pending home sales'],
   
        # lv1: speak
        'central bank speak': [
            'fomc member',
            'boe gov',
            'ecb president',
            'boj gov',
            'rba gov',
            'rbnz gov',
            'boc gov',
            'snb chairman',
            'mpc member',
            'gov council member',
            'gov board member'
        ],
        'press conference': [
            'press conference'
        ],
        'government official speak': [
            'fed chair powell speaks',
            'president biden speaks',
            'fed chair powell testifies'
        ],

        # lv1: submit
        'budget release': [
            'annual budget release',
            'federal budget balance',
            'french gov budget balance'
        ],
        'economic projections': [
            'fomc economic projections'
        ],

        # lv1: monetary policy
        'meeting minutes': [
            'fomc meeting minutes',
            'monetary policy meeting minutes',
            'fpc meeting minutes',
            'ecb monetary policy meeting accounts'
        ],
        'policy statement/report': [
            'monetary policy statement',
            'monetary policy report',
            'boe monetary policy report',
            'rba monetary policy statement',
            'boc monetary policy report',
            'fed monetary policy report',
            'snb monetary policy assessment',
            'rba monetary policy statement',
            'rbnz monetary policy statement',
            'monetary policy summary'
        ],
        'rate statement/policy rate': [
            'boj policy rate',
            'boc rate statement',
            'rba rate statement',
            'rbnz rate statement',
            'snb policy rate'
        ],
        'monetary policy hearings': [
            'monetary policy report hearings'
        ],
        'rate decision': [
            'official cash rate',
            'federal funds rate',
            'main refinancing rate',
            'cash rate',
            'mpc official bank rate votes',
            'official bank rate',
            'overnight rate',
        ],
        'policy statement': [
            'fomc statement',
        ],
        'outlook report': [
            'boj outlook report',
        ],
        
        # lv1: holiday    
        'bank holiday': ['french bank holiday', 'german bank holiday', 'italian bank holiday', 'bank holiday'], 
        'public holiday': ['public holiday'],

        # lv1: economic indicators (updated)
        'consumer sentiment': [
            'prelim uom consumer sentiment',
            'revised uom consumer sentiment'
        ],
        'consumer confidence': [
            'cb consumer confidence'
        ],
        'employment indicators': [
            'claimant count change',
            'average hourly earnings m/m',
            'wage price index q/q'
        ],
        'manufacturing index': [
            'empire state manufacturing index',
            'durable goods orders m/m'
        ],

        # lv1: political events (updated)
        'parliamentary elections': [
            'french parliamentary elections',
            'european parliamentary elections',
            'parliamentary elections'
        ],
        'summit': [
            'euro summit'
        ]
    }

    # Level 3 - Time Frame
    level_3_categories = {
        'm/m': ['m/m', 'month-over-month'],
        'y/y': ['y/y', 'year-over-year'],
        'q/q': ['q/q', 'quarter-over-quarter'],
        '10-year': ['10-y'],
        '30-year': ['30-y'],
        'monthly': ['monthly'],
        'annual': ['annual', 'year'],
        'quarterly': ['quarterly'],
        'q/y': ['q/y', 'quarter-over-year']  # Bổ sung từ khóa "q/y"
    }

    # Initialize categories
    level_1 = 'other'
    level_2 = 'unspecified'
    level_3 = 'unspecified'

    # Categorize Level 1
    for key, keywords in primary_categories.items():
        if any(keyword in event_name for keyword in keywords):
            level_1 = key
            break

    # Categorize Level 2
    for key, keywords in level_2_categories.items():
        if any(keyword in event_name for keyword in keywords):
            level_2 = key
            break

    # Categorize Level 3
    for key, keywords in level_3_categories.items():
        if any(keyword in event_name for keyword in keywords):
            level_3 = key
            break

    return level_1, level_2, level_3

# Áp dụng hàm phân loại
df_combined[['category_lv1', 'category_lv2', 'category_lv3']] = df_combined['event'].apply(lambda x: pd.Series(categorize_event(x)))

# In ra kết quả
df_combined.head(5)
# Out:
#     date     time currency impact         event actual forecast previous  \
# 0  Jan 1  All Day      NZD   gray  Bank Holiday    NaN      NaN      NaN
# 1  Jan 1  All Day      AUD   gray  Bank Holiday    NaN      NaN      NaN
# 2  Jan 1  All Day      JPY   gray  Bank Holiday    NaN      NaN      NaN
# 3  Jan 1  All Day      CNY   gray  Bank Holiday    NaN      NaN      NaN
# 4  Jan 1  All Day      CHF   gray  Bank Holiday    NaN      NaN      NaN
#
#   category_lv1  category_lv2 category_lv3
# 0      holiday  bank holiday  unspecified
# 1      holiday  bank holiday  unspecified
# 2      holiday  bank holiday  unspecified
# 3      holiday  bank holiday  unspecified
# 4      holiday  bank holiday  unspecified

# %% [markdown]
# ### Refinement process

# %% [markdown]
# #### GDP

# %%
# Refinement process for GDP events
def refine_gdp_classification(df):
    # Bước 1: Lọc tất cả các sự kiện GDP
    gdp_events = df[df['category_lv1'] == 'gdp'].copy()  # Tạo một bản sao của DataFrame gốc

    # Bước 2: Lọc ra 4 cột quan trọng
    gdp_events = gdp_events[['event', 'category_lv1', 'category_lv2', 'category_lv3']]

    # Bước 3: Lọc các sự kiện chưa được phân loại cụ thể ở Level 2 hoặc Level 3
    unspecified_gdp_events = gdp_events[
        (gdp_events['category_lv2'] == 'unspecified') |
        (gdp_events['category_lv3'] == 'unspecified')
        ]

    # Bước 4: Loại bỏ các sự kiện trùng lặp để chỉ lấy các sự kiện duy nhất
    unique_unspecified_gdp_events = unspecified_gdp_events.drop_duplicates()

    # Bước 5: In kết quả để phân loại tay
    return unique_unspecified_gdp_events

# Áp dụng quy trình refinement cho các sự kiện GDP
refined_gdp_df = refine_gdp_classification(df_combined)

# In ra các sự kiện GDP chưa được phân loại đúng
refined_gdp_df
# Out:
#                   event category_lv1  category_lv2 category_lv3
# 146  NIESR GDP Estimate          gdp  gdp estimate  unspecified

# %% [markdown]
# - **Final Result** on GDP as expectation

# %% [markdown]
# #### Inflation

# %%
# Refinement process for GDP events
def inflation_events_classification(df):
    # Bước 1: Lọc tất cả các sự kiện GDP
    inflation_events = df[df['category_lv1'] == 'inflation'].copy()  # Tạo một bản sao của DataFrame gốc

    # Bước 2: Lọc ra 4 cột quan trọng
    inflation_events = inflation_events[['event', 'category_lv1', 'category_lv2', 'category_lv3']]

    # Bước 3: Lọc các sự kiện chưa được phân loại cụ thể ở Level 2 hoặc Level 3
    unspecified_inflation_events = inflation_events[
        (inflation_events['category_lv2'] == 'unspecified') |
        (inflation_events['category_lv3'] == 'unspecified')
        ]

    # Bước 4: Loại bỏ các sự kiện trùng lặp để chỉ lấy các sự kiện duy nhất
    unique_unspecified_inflation_events = unspecified_inflation_events.drop_duplicates()

    # Bước 5: In kết quả để phân loại tay
    return unique_unspecified_inflation_events

# Áp dụng quy trình refinement cho các sự kiện GDP
refined_inflation_events = inflation_events_classification(df_combined)

# In ra các sự kiện GDP chưa được phân loại đúng
refined_inflation_events
# Out:
#                                      event category_lv1  \
# 151                 MI Inflation Gauge m/m    inflation
# 220              MI Inflation Expectations    inflation
# 252      Prelim UoM Inflation Expectations    inflation
# 425     Revised UoM Inflation Expectations    inflation
# 513   Cleveland Fed Inflation Expectations    inflation
# 521             Inflation Expectations q/q    inflation
# 959        Consumer Inflation Expectations    inflation
# 1055                  BOE Inflation Letter    inflation
#
#                 category_lv2 category_lv3
# 151              unspecified          m/m
# 220   inflation expectations  unspecified
# 252   inflation expectations  unspecified
# 425   inflation expectations  unspecified
# 513   inflation expectations  unspecified
# 521              unspecified          q/q
# 959   inflation expectations  unspecified
# 1055        inflation letter  unspecified

# %% [markdown]
#  # Checklist
#
#
#
# [x] 1. GDP
#
# [x] 2. Inflation
#
# [x] 3. Bond
#
# [x] 4. Employment Indicators
#
# [x] 5. Production Indicators
#
# [x] 6. Sales Indicators
#
# [x] 7. Speak
#
# [x] 8. Submit
#
# [x] 9. Monetary Policy
#
# [x] 10. Holiday

# %% [markdown]
# #### General Refinement Process for Events

# %%
def events_classification(df, category):
    # Step 1: Filter all events based on the given category
    events = df[df['category_lv1'] == category].copy()  # Create a copy of the original DataFrame

    # Step 2: Filter out the 4 important columns
    events = events[['event', 'category_lv1', 'category_lv2', 'category_lv3', 'impact', 'actual']]

    # Step 3: Filter events that are unspecified in Level 2 or Level 3
    unspecified_events = events[
        (events['category_lv2'] == 'unspecified') |
        (events['category_lv3'] == 'unspecified')
    ]

    # Step 4: Drop duplicate events to get only unique events
    unique_unspecified_events = unspecified_events.drop_duplicates()

    # Step 5: Return the results for manual classification
    return unique_unspecified_events

# Apply the refinement process for a specific category (e.g., "inflation")
refined_events = events_classification(df_combined, 'other')

# Print out the events that haven't been properly classified
# refined_events.category_lv1

refined_events[refined_events['impact'] == 'red']
# Out:
# Empty DataFrame
# Columns: [event, category_lv1, category_lv2, category_lv3, impact, actual]
# Index: []

# %% [markdown]
# ## Finalize

# %%
df_combined.columns
# Out:
# Index(['date', 'time', 'currency', 'impact', 'event', 'actual', 'forecast',
#        'previous', 'category_lv1', 'category_lv2', 'category_lv3'],
#       dtype='object')

# %% [markdown]
# Validating the categories in your dataset is an important step to ensure that the categorization logic is working correctly. Here’s how you can validate the categories:
#
# ### 1. **Check for Unspecified Categories:**
#    - You should first check how many events have been categorized as "unspecified" in any of the three levels. This will help you identify if there are events that haven’t been categorized properly.
#
#    ```python
#    # Check for unspecified categories in Level 1, Level 2, and Level 3
#    unspecified_lv1 = df_combined[df_combined['category_lv1'] == 'unspecified']
#    unspecified_lv2 = df_combined[df_combined['category_lv2'] == 'unspecified']
#    unspecified_lv3 = df_combined[df_combined['category_lv3'] == 'unspecified']
#
#    print(f"Unspecified in Level 1: {len(unspecified_lv1)}")
#    print(f"Unspecified in Level 2: {len(unspecified_lv2)}")
#    print(f"Unspecified in Level 3: {len(unspecified_lv3)}")
#    ```
#
# ### 2. **Review Sample Events:**
#    - Manually review a sample of events in each category to ensure they are being categorized correctly. You can take a random sample or review all events within a specific category.
#
#    ```python
#    # Sample of events in a specific category to manually validate
#    sample_events = df_combined[df_combined['category_lv1'] == 'inflation'].sample(10)
#    print(sample_events)
#    ```
#
# ### 3. **Cross-Check with Known Data:**
#    - Compare the categorized data against known, validated datasets or benchmarks. If you have access to a source where similar events are categorized, you can cross-check your results.
#
#    ```python
#    # Assume you have a benchmark dataset
#    benchmark_df = pd.read_csv('benchmark_categorized_events.csv')
#
#    # Merge and compare
#    comparison_df = df_combined.merge(benchmark_df, on='event', suffixes=('_yours', '_benchmark'))
#
#    # Check for differences
#    mismatches = comparison_df[(comparison_df['category_lv1_yours'] != comparison_df['category_lv1_benchmark']) |
#                               (comparison_df['category_lv2_yours'] != comparison_df['category_lv2_benchmark']) |
#                               (comparison_df['category_lv3_yours'] != comparison_df['category_lv3_benchmark'])]
#    print(f"Mismatches found: {len(mismatches)}")
#    ```
#
# ### 4. **Visualize the Category Distribution:**
#    - Visualize how events are distributed across categories to identify any anomalies or unexpected distributions.
#
#    ```python
#    import matplotlib.pyplot as plt
#
#    # Distribution of events by Level 1 category
#    df_combined['category_lv1'].value_counts().plot(kind='bar')
#    plt.title('Distribution of Events by Level 1 Category')
#    plt.xlabel('Category Level 1')
#    plt.ylabel('Number of Events')
#    plt.show()
#
#    # Distribution of unspecified categories
#    unspecified_lv2['category_lv1'].value_counts().plot(kind='bar')
#    plt.title('Unspecified Events by Level 1 Category in Level 2')
#    plt.xlabel('Category Level 1')
#    plt.ylabel('Number of Unspecified Events')
#    plt.show()
#    ```
#
# ### 5. **Use Assertions:**
#    - Implement assertions to validate that specific known events fall into the expected categories.
#
#    ```python
#    # Assert known event is categorized correctly
#    assert df_combined[df_combined['event'] == 'CPI y/y']['category_lv1'].values[0] == 'inflation', "CPI y/y should be in 'inflation'"
#    assert df_combined[df_combined['event'] == 'FOMC Meeting Minutes']['category_lv1'].values[0] == 'monetary policy', "FOMC Meeting Minutes should be in 'monetary policy'"
#    ```
#
# ### 6. **Iterative Refinement:**
#    - Based on the findings from the above steps, refine the categorization logic by updating or adding keywords, adjusting categories, and rerunning the categorization.
#
# ### 7. **Documentation:**
#    - Document any changes you make during the validation process. Keeping a log of adjustments ensures you can track why certain events were reclassified.
#
# ### Final Steps:
# - After validation, if a significant number of events are categorized as "unspecified" or incorrectly classified, it indicates the need for refinement in the category logic.
# - Continue refining your categorization logic based on validation results until the accuracy meets your standards.

# %% [markdown]
# ## Cleaning Data

# %%
df_combined.dtypes
# Out:
# date            object
# time            object
# currency        object
# impact          object
# event           object
# actual          object
# forecast        object
# previous        object
# category_lv1    object
# category_lv2    object
# category_lv3    object
# dtype: object

# %%
# 1. Xử lý dữ liệu time
def process_time(time_str):
    if time_str == 'All Day':
        return '12:00am'
    elif time_str.startswith('Day'):
        return '12:00am'
    else:
        return time_str

df_combined['time'] = df_combined['time'].apply(process_time)

# Chuyển đổi cột time sang dạng giờ phút giây
df_combined['time'] = pd.to_datetime(df_combined['time'], format='%I:%M%p', errors='coerce').dt.strftime('%H:%M:%S')

# 2. Xử lý dữ liệu date
# Thêm năm mặc định, ví dụ 2024
df_combined['date'] = pd.to_datetime(df_combined['date'] + ' 2024', format='%b %d %Y')

# 3. Hợp nhất cột date và time thành cột datetime và đánh index
# Kết hợp thời gian với cột ngày
df_combined['datetime'] = df_combined['date'] + pd.to_timedelta(df_combined['time'])

# 4. Kiểm tra DataFrame đã đánh index chưa và index là cột nào
is_index_set = df_combined.index.is_monotonic_increasing  # True nếu index được sắp xếp từ nhỏ đến lớn
df_combined.reset_index(drop=True, inplace=True)

# %%
# Hàm chuyển đổi giá trị thành float, xử lý cả phần trăm và các ký tự K, M, B, T
def convert_to_float(value):
    if isinstance(value, str):
        multiplier = 1
        value = value.strip()  # Loại bỏ khoảng trắng ở đầu và cuối nếu có

        if value.endswith('%'):
            # Nếu giá trị kết thúc bằng '%', chuyển đổi thành phần trăm
            value = value[:-1]
            try:
                return float(value) / 100
            except ValueError:
                return np.nan

        if value.endswith('K'):
            multiplier = 1e3
            value = value[:-1]
        elif value.endswith('M'):
            multiplier = 1e6
            value = value[:-1]
        elif value.endswith('B'):
            multiplier = 1e9
            value = value[:-1]
        elif value.endswith('T'):
            multiplier = 1e12
            value = value[:-1]

        try:
            return float(value) * multiplier
        except ValueError:
            return np.nan
    try:
        return float(value) if value != '' else np.nan
    except ValueError:
        return np.nan

# Ứng dụng hàm chuyển đổi cho các cột cần thiết
for col in ['forecast', 'previous', 'actual']:
    df_combined[col] = df_combined[col].apply(convert_to_float)

# Chuyển đổi các cột sang float64
df_combined['forecast'] = df_combined['forecast'].astype('float64')
df_combined['previous'] = df_combined['previous'].astype('float64')
df_combined['actual'] = df_combined['actual'].astype('float64')

# Kiểm tra kết quả
print(df_combined[['forecast', 'previous', 'actual']])
# Out:
#          forecast     previous       actual
# 0             NaN          NaN          NaN
# 1             NaN          NaN          NaN
# 2             NaN          NaN          NaN
# 3             NaN          NaN          NaN
# 4             NaN          NaN          NaN
# ...           ...          ...          ...
# 2769        0.001        0.003        0.002
# 2770        0.010        0.012        0.009
# 2771       44.800       47.400       45.300
# 2772        0.014       -0.019        0.048
# 2773 -1600000.000 -3700000.000 -3400000.000
#
# [2774 rows x 3 columns]

# %%
df_combined.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# currency                object
# impact                  object
# event                   object
# actual                 float64
# forecast               float64
# previous               float64
# category_lv1            object
# category_lv2            object
# category_lv3            object
# datetime        datetime64[ns]
# dtype: object

# %%
# Thứ tự cột mong muốn
column_order = [
    'datetime', 'currency', 'impact', 'event',
    'actual', 'forecast', 'previous',
    'category_lv1', 'category_lv2', 'category_lv3',
    'date', 'time'
]

# Sắp xếp lại các cột bằng cách chỉ định thứ tự cột mới
df_combined = df_combined[column_order]

df_combined
# Out:
#                 datetime currency  impact                      event  \
# 0    2024-01-01 00:00:00      NZD    gray               Bank Holiday
# 1    2024-01-01 00:00:00      AUD    gray               Bank Holiday
# 2    2024-01-01 00:00:00      JPY    gray               Bank Holiday
# 3    2024-01-01 00:00:00      CNY    gray               Bank Holiday
# 4    2024-01-01 00:00:00      CHF    gray               Bank Holiday
# ...                  ...      ...     ...                        ...
# 2769 2024-07-31 19:30:00      CAD     red                    GDP m/m
# 2770 2024-07-31 19:30:00      USD     red  Employment Cost Index q/q
# 2771 2024-07-31 20:45:00      USD  orange                Chicago PMI
# 2772 2024-07-31 21:00:00      USD     red     Pending Home Sales m/m
# 2773 2024-07-31 21:30:00      USD  yellow      Crude Oil Inventories
#
#            actual     forecast     previous           category_lv1  \
# 0             NaN          NaN          NaN                holiday
# 1             NaN          NaN          NaN                holiday
# 2             NaN          NaN          NaN                holiday
# 3             NaN          NaN          NaN                holiday
# 4             NaN          NaN          NaN                holiday
# ...           ...          ...          ...                    ...
# 2769        0.002        0.001        0.003                    gdp
# 2770        0.009        0.010        0.012  employment indicators
# 2771       45.300       44.800       47.400  production indicators
# 2772        0.048        0.014       -0.019       sales indicators
# 2773 -3400000.000 -1600000.000 -3700000.000                  other
#
#                category_lv2 category_lv3       date      time
# 0              bank holiday  unspecified 2024-01-01  00:00:00
# 1              bank holiday  unspecified 2024-01-01  00:00:00
# 2              bank holiday  unspecified 2024-01-01  00:00:00
# 3              bank holiday  unspecified 2024-01-01  00:00:00
# 4              bank holiday  unspecified 2024-01-01  00:00:00
# ...                     ...          ...        ...       ...
# 2769            gdp general          m/m 2024-07-31  19:30:00
# 2770  employment cost index          q/q 2024-07-31  19:30:00
# 2771            unspecified  unspecified 2024-07-31  20:45:00
# 2772     pending home sales          m/m 2024-07-31  21:00:00
# 2773            unspecified  unspecified 2024-07-31  21:30:00
#
# [2774 rows x 12 columns]

# %% [markdown]
# ### Export one single table to silver directory for viz

# %%
# Đặt tên cho tệp CSV
csv_file_name = 'final_transformed_data.csv'  
csv_file_path = f'/Users/datpro/Documents/gitdatpro/ff-transform-data/data/silver/{csv_file_name}'

# Xuất DataFrame dưới dạng CSV với tên tệp đã chọn
df_combined.to_csv(csv_file_path, index=False)

print(f"DataFrame đã được xuất thành công với tên {csv_file_name} tại {csv_file_path}")
# Out:
# DataFrame đã được xuất thành công với tên final_transformed_data.csv tại /Users/datpro/Documents/gitdatpro/ff-transform-data/data/silver/final_transformed_data.csv
